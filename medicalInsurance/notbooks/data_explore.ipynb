# %%
import sys ,  os 
sys.path.append(os.path.abspath(".."))
from src.data import load_data
from src.helper import data_processing 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=load_data()
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.13)

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
sns.set_theme()
plt.figure(figsize=(8,8))
sns.displot(df['age'])
plt.title('Age distribution')
plt.show()

# %%
sns.set_theme()
plt.figure(figsize=(8,8))
sns.countplot(x='sex' , data=df ,color='green')
plt.title('Age distribution')
plt.show()

# %%
sns.set_theme()
plt.figure(figsize=(8,8))
sns.displot(df['bmi'])
plt.title('Age distribution')
plt.show()
#alot of ppl in the overwieght side

# %%
sns.set_theme()
plt.figure(figsize=(8,8))
sns.countplot(x='children' , data=df )
plt.title('children distribution')
plt.show()

# %%
sns.set_theme()
plt.figure(figsize=(8,8))
sns.displot(df['charges'])
plt.title('charge distribution')
plt.show()

# %%
df=data_processing(df)
# Out:
# c:\Users\kakas\Desktop\50 project i think\Ml projects\medicalInsurance\src\helper.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'sex' : {'male' :1 , 'female' : 0}} , inplace= True)
# c:\Users\kakas\Desktop\50 project i think\Ml projects\medicalInsurance\src\helper.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'smoker' : {'yes' : 1 , "no" : 0 }} , inplace = True)
# c:\Users\kakas\Desktop\50 project i think\Ml projects\medicalInsurance\src\helper.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'region' : { 'southeast' : 0, 'southwest' : 1   ,'northeast' : 2 , 'northwest' : 3  }} , inplace=True)

# %%
df['region'].unique()
# Out:
# array([1, 0, 3, 2])
